# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_breast_cancer()
features = data.data
labels = data.target

model = svm.SVC(kernel='linear')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=117, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted)))
print('Recall {}'.format(recall_score(testL, predicted)))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9473684210526315
# Precision 0.9375
# Recall 0.9868421052631579
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92        38
#            1       0.94      0.99      0.96        76
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.93      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_breast_cancer()
features = data.data
labels = data.target

model = svm.SVC(kernel='poly')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=117, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted)))
print('Recall {}'.format(recall_score(testL, predicted)))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9122807017543859
# Precision 0.9024390243902439
# Recall 0.9736842105263158
#               precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86        38
#            1       0.90      0.97      0.94        76
#
#     accuracy                           0.91       114
#    macro avg       0.92      0.88      0.90       114
# weighted avg       0.91      0.91      0.91       114

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_breast_cancer()
features = data.data
labels = data.target

model = svm.SVC(kernel='rbf')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=117, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted)))
print('Recall {}'.format(recall_score(testL, predicted)))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9210526315789473
# Precision 0.9135802469135802
# Recall 0.9736842105263158
#               precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87        38
#            1       0.91      0.97      0.94        76
#
#     accuracy                           0.92       114
#    macro avg       0.93      0.89      0.91       114
# weighted avg       0.92      0.92      0.92       114

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

model = svm.SVC(kernel='linear')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=117, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9805555555555555
# Precision 0.9810407398497569
# Recall 0.9805555555555555
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       0.97      0.97      0.97        32
#            2       0.97      1.00      0.99        36
#            3       1.00      0.94      0.97        31
#            4       0.97      1.00      0.99        33
#            5       0.97      1.00      0.99        33
#            6       1.00      0.97      0.99        40
#            7       0.97      1.00      0.99        37
#            8       0.94      0.97      0.95        31
#            9       1.00      0.95      0.97        39
#
#     accuracy                           0.98       360
#    macro avg       0.98      0.98      0.98       360
# weighted avg       0.98      0.98      0.98       360

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

model = svm.SVC(kernel='poly')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=117, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9805555555555555
# Precision 0.9809997059997061
# Recall 0.9805555555555555
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       0.97      1.00      0.98        32
#            2       0.97      1.00      0.99        36
#            3       1.00      0.94      0.97        31
#            4       1.00      1.00      1.00        33
#            5       0.97      0.97      0.97        33
#            6       0.97      0.97      0.97        40
#            7       0.95      1.00      0.97        37
#            8       0.97      0.97      0.97        31
#            9       1.00      0.95      0.97        39
#
#     accuracy                           0.98       360
#    macro avg       0.98      0.98      0.98       360
# weighted avg       0.98      0.98      0.98       360

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

# decreasing value of C tends to reduce accuracy of the model
model = svm.SVC(kernel='poly', C=1000)

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=117, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9833333333333333
# Precision 0.9841417268661851
# Recall 0.9833333333333333
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       1.00      1.00      1.00        32
#            2       1.00      1.00      1.00        36
#            3       1.00      0.94      0.97        31
#            4       1.00      1.00      1.00        33
#            5       0.97      0.97      0.97        33
#            6       0.97      0.97      0.97        40
#            7       0.97      1.00      0.99        37
#            8       0.91      1.00      0.95        31
#            9       1.00      0.95      0.97        39
#
#     accuracy                           0.98       360
#    macro avg       0.98      0.98      0.98       360
# weighted avg       0.98      0.98      0.98       360

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

model = svm.SVC(kernel='rbf')

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=117, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9805555555555555
# Precision 0.9811542622327684
# Recall 0.9805555555555555
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       0.97      1.00      0.98        32
#            2       0.97      1.00      0.99        36
#            3       1.00      0.94      0.97        31
#            4       1.00      0.97      0.98        33
#            5       0.97      0.97      0.97        33
#            6       0.98      1.00      0.99        40
#            7       0.95      1.00      0.97        37
#            8       0.97      1.00      0.98        31
#            9       1.00      0.92      0.96        39
#
#     accuracy                           0.98       360
#    macro avg       0.98      0.98      0.98       360
# weighted avg       0.98      0.98      0.98       360

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs, load_breast_cancer, load_digits
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from mlxtend.plotting import plot_decision_regions

data = load_digits()
features = data.data
labels = data.target

# decreasing value of C tends to reduce accuracy of the model
model = svm.SVC(kernel='rbf', C=100000)

trainX, testX, trainL, testL = train_test_split(features, labels, random_state=132, test_size=0.2)
model.fit(trainX, trainL)

predicted = model.predict(testX)

print('Accuracy {}'.format(accuracy_score(testL, predicted)))
print('Precision {}'.format(precision_score(testL, predicted, average='weighted')))
print('Recall {}'.format(recall_score(testL, predicted, average='weighted')))

print(classification_report(testL, predicted))
# Out:
# Accuracy 0.9916666666666667
# Precision 0.992033950617284
# Recall 0.9916666666666667
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       1.00      1.00      1.00        41
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        28
#            4       1.00      1.00      1.00        27
#            5       1.00      0.97      0.99        38
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        46
#            8       0.92      1.00      0.96        23
#            9       0.97      0.95      0.96        37
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360
